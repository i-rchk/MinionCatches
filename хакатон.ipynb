# %% [markdown]
# <a href="https://colab.research.google.com/github/i-rchk/MinionCatches/blob/main/%D1%85%D0%B0%D0%BA%D0%B0%D1%82%D0%BE%D0%BD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
users = pd.read_csv('users.csv')
exp = pd.read_csv('experiment_assignments.csv')
sessions = pd.read_csv('sessions.csv')
impressions = pd.read_csv('impressions.csv')
clicks = pd.read_csv('clicks.csv')
orders = pd.read_csv('orders.csv')
products = pd.read_csv('products.csv')
sellers = pd.read_csv('sellers.csv')
tickets = pd.read_csv('support_tickets.csv')
premium = pd.read_csv('premium_subscriptions.csv')
dd = pd.read_csv('data_dictionary.csv')

# %%
tables = {
    'users': users, 'experiment_assignments': exp, 'sessions': sessions,
    'impressions': impressions, 'clicks': clicks, 'orders': orders,
    'products': products, 'sellers': sellers, 'support_tickets': tickets,
    'premium_subscriptions': premium,
}

for name, df in tables.items():
    print(f"--- {name} ---")
    print("Размер:", df.shape)
    print(df.dtypes)
    print()
    print(df.head)
    print()
# Out:
# --- users ---
# Размер: (50000, 8)
# user_id              object
# registration_date    object
# region               object
# device               object
# age_group            object
# traffic_source       object
# is_premium            int64
# is_bot_candidate      int64
# dtype: object
#
# <bound method NDFrame.head of         user_id registration_date          region   device age_group  \
# 0      u_000001        2026-04-29           Volga  android     18-24
# 1      u_000002        2026-02-25  Central Russia  android     35-44
# 2      u_000003        2026-04-01          Moscow      web     18-24
# 3      u_000004        2026-03-08            Ural      ios     25-34
# 4      u_000005        2025-07-28  Central Russia  android     18-24
# ...         ...               ...             ...      ...       ...
# 49995  u_049996        2026-06-13          Moscow  android     45-54
# 49996  u_049997        2026-05-27        Far East      web     25-34
# ...

# %%
users = pd.read_csv('users.csv', parse_dates=['registration_date'])
orders = pd.read_csv('orders.csv', parse_dates=['order_date', 'return_date'])
